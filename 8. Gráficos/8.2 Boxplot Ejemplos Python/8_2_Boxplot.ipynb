# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from statsmodels.stats.diagnostic import normal_ad
from scipy.stats import shapiro
import seaborn as sns

# %% [markdown]
# # 2 grupos

# %%
#https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/refs/heads/main/8.%20Gráficos/8.2%20Boxplot%20Ejemplos%20Python/boxplot2groups.csv

# %%
from urllib.parse import quote

ruta = "8. Gráficos/8.2 Boxplot Ejemplos Python/boxplot2groups.csv"

print(quote(ruta))
# Out:
# 8.%20Gr%C3%A1ficos/8.2%20Boxplot%20Ejemplos%20Python/boxplot2groups.csv

# %%
preruta = "https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/main/"

# %%
rutaFinal = preruta + quote(ruta)
print(rutaFinal)
# Out:
# https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/main/8.%20Gr%C3%A1ficos/8.2%20Boxplot%20Ejemplos%20Python/boxplot2groups.csv

# %%
df=pd.read_csv(rutaFinal)
df.head()
# Out:
#       IQ  School
# 0  147.0     2.0
# 1  140.0     2.0
# 2  141.0     1.0
# 3  141.0     1.0
# 4  142.0     2.0

# %%
import requests

r = requests.get(rutaFinal)
print(r.status_code)
# Out:
# 200

# %%
import pandas as pd
import requests
from io import StringIO

r = requests.get(rutaFinal)

print(r.status_code)   # debería mostrar 200

df = pd.read_csv(StringIO(r.text))

df.head()
# Out:
# 200
#       IQ  School
# 0  147.0     2.0
# 1  140.0     2.0
# 2  141.0     1.0
# 3  141.0     1.0
# 4  142.0     2.0

# %%
#df=pd.read_csv('/content/boxplot2groups.csv')
#df.head()

# %%
df.School[df.School==1.0]='Welch'
df.School[df.School==2.0]='St. Jude'
df.head()
# Out:
# /tmp/ipykernel_1874/3097887860.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.School[df.School==1.0]='Welch'
# ...

# %%
ax=sns.boxplot(x="School", y="IQ", data=df, order=["Welch", "St. Jude"], width=0.4)

# %% [markdown]
# # 4 grupos

# %%
preruta2= "https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/main/"

# %%
ruta2 = "8. Gráficos/8.2 Boxplot Ejemplos Python/boxplot4groups.csv"

# %%
rutaFinal= preruta2 + quote(ruta2)
print(rutaFinal)
# Out:
# https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/main/8.%20Gr%C3%A1ficos/8.2%20Boxplot%20Ejemplos%20Python/boxplot4groups.csv

# %%
df=pd.read_csv(rutaFinal)
df.head()
# Out:
#    dose  rating
# 0   1.0     6.0
# 1   1.0     4.0
# 2   1.0     6.0
# 3   1.0     5.0
# 4   1.0     4.0

# %%
#df=pd.read_csv('/content/boxplot4groups.csv')
#df.head()

# %%
df.dose[df.dose==1.0]='100 mg'
df.dose[df.dose==2.0]='250 mg'
df.dose[df.dose==3.0]='500 mg'
df.dose[df.dose==4.0]='1000 mg'
df.head()
# Out:
# /tmp/ipykernel_1874/2875491765.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.dose[df.dose==1.0]='100 mg'
# ...

# %%
ax=sns.boxplot(x="dose", y="rating", data=df, order=['100 mg','250 mg','500 mg', '1000 mg'], width=0.4)

# %%
plt.figure(figsize=(15,5))
ax=sns.boxplot(x="dose", y="rating", data=df, order=['100 mg','250 mg','500 mg', '1000 mg'], width=0.4,palette="Blues")
# Out:
# /tmp/ipykernel_1874/3223328279.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.boxplot(x="dose", y="rating", data=df, order=['100 mg','250 mg','500 mg', '1000 mg'], width=0.4,palette="Blues")

# %% [markdown]
# # Medidas repetidas

# %%
# ruta 3
preruta3 = "https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/main/"

# %%
postruta3 = "8. Gráficos/8.2 Boxplot Ejemplos Python/boxplotrep.csv"

# %%
rutaFinal3 = preruta3 + quote(postruta3)
print(rutaFinal3)
# Out:
# https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/main/8.%20Gr%C3%A1ficos/8.2%20Boxplot%20Ejemplos%20Python/boxplotrep.csv

# %%
df = pd.read_csv(rutaFinal3)
df.head()
# Out:
#         brand  rating
# 0  Pine Creek     6.0
# 1  Pine Creek     7.0
# 2  Pine Creek     6.0
# 3  Pine Creek     7.0
# 4  Pine Creek     5.0

# %%
#df=pd.read_csv('/content/boxplotrep.csv')
#df.head()

# %%
plt.figure(figsize=(15,5))
ax=sns.boxplot(x="brand", y="rating", data=df, width=0.4,palette="Set3")
# Out:
# /tmp/ipykernel_1874/375911142.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.boxplot(x="brand", y="rating", data=df, width=0.4,palette="Set3")
