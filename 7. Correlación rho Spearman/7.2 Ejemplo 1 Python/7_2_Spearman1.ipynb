# %% [markdown]
# <a href="https://colab.research.google.com/github/sebaspatric/curso-no-parametrica/blob/main/7.%20Correlaci%C3%B3n%20rho%20Spearman/7.2%20Ejemplo%201%20Python/7_2_Spearman1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy import stats

# %%
#link = "https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/refs/heads/main/7.%20Correlación%20rho%20Spearman/7.2%20Ejemplo%201%20Python/employeeratings.csv"

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/sebaspatric/curso-no-parametrica/main/7.%20Correlaci%C3%B3n%20rho%20Spearman/7.2%20Ejemplo%201%20Python/employeeratings.csv"

df = pd.read_csv(url)
print(df.head())
# Out:
#    Score  Rating
# 0   74.0     1.0
# 1   75.0     3.0
# 2   78.0     2.0
# 3   79.0     3.0
# 4   73.0     1.0

# %%
corr, p = stats.spearmanr(df.Score, df.Rating)

print('Correlation=%.3f, p=%.3f' % (corr, p))
# interpretación
alpha = 0.05
if p > alpha:
	print('No rechazamos H0: Correlación no significativa.')
else:
	print('Rechazamos H0: Correlación significativa.')
# Out:
# Correlation=0.763, p=0.000
# Rechazamos H0: Correlación significativa.
